# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
coffee = pd.read_excel("D://Data Analytics//Utkarsh_IMT//Python//exercise//Coffee.xlsx")

# %%
coffee.columns
# Out:
# Index(['Area Code', 'Market', 'Market Size', 'Product', 'Product Line',
#        'Product Type', 'State', 'Type', 'Budget COGS', 'Budget Margin',
#        'Budget Profit', 'Budget Sales', 'COGS', 'Inventory', 'Margin',
#        'Marketing', 'Profit', 'Sales', 'Total Expenses'],
#       dtype='object')

# %%
coffee.head()
# Out:
#    Area Code   Market   Market Size            Product Product Line  \
# 0        719  Central  Major Market           Amaretto        Beans
# 1        970  Central  Major Market          Colombian        Beans
# 2        970  Central  Major Market  Decaf Irish Cream        Beans
# 3        303  Central  Major Market          Green Tea       Leaves
# 4        303  Central  Major Market        Caffe Mocha        Beans
#
#   Product Type     State     Type  Budget COGS  Budget Margin  Budget Profit  \
# 0       Coffee  Colorado  Regular           90            130            100
# 1       Coffee  Colorado  Regular           80            110             80
# 2       Coffee  Colorado    Decaf          100            140            110
# 3          Tea  Colorado  Regular           30             50             30
# 4     Espresso  Colorado  Regular           60             90             70
#
#    Budget Sales  COGS  Inventory  Margin  Marketing  Profit  Sales  \
# ...

# %%
#  1. Budget COGS (Cost of Goods Sold)
# This is the estimated cost of producing the goods you expect to sell.

# Calculation:
# 800 units × ₹100 = ₹80,000
# ✅ Budget COGS = ₹80,000

# 📘 2. Budget Sales
# This is the expected revenue from selling 800 units.

# Calculation:
# 800 units × ₹150 = ₹1,20,000
# ✅ Budget Sales = ₹1,20,000

# 📘 3. Budget Margin
# This is the expected gross profit (before other expenses).

# Calculation:
# Budget Sales − Budget COGS
# ₹1,20,000 − ₹80,000 = ₹40,000
# ✅ Budget Margin = ₹40,000

# 📘 4. Budget Profit
# This is the expected net profit after subtracting all costs, including fixed expenses.

# Calculation:
# Budget Margin − Other expenses
# ₹40,000 − ₹5,000 = ₹35,000
# ✅ Budget Profit = ₹35,000

# Now suppose actual results differ slightly:

# You actually sold 850 units

# Actual cost per unit = ₹105

# Actual selling price = ₹145

# Other expenses = ₹6,000

# You still produced 1,000 units

# 📘 5. COGS (Actual)
# Actual cost of goods you sold, not produced.

# Calculation:
# 850 units × ₹105 = ₹89,250
# ✅ COGS = ₹89,250

# 📘 6. Inventory
# You produced 1,000 units, sold 850 → 150 units remain in stock.

# Calculation (at cost):
# 150 units × ₹105 = ₹15,750
# ✅ Inventory = ₹15,750

# 📘 7. Margin (Actual)
# This is your actual gross profit.

# Calculation:
# 850 units × ₹145 = ₹1,23,250 (actual sales)
# Margin = Sales − COGS = ₹1,23,250 − ₹89,250 = ₹34,000
# ✅ Margin = ₹34,000

# %%
coffee.shape
# Out:
# (4248, 19)

# %%
coffee.dtypes
# Out:
# Area Code          int64
# Market            object
# Market Size       object
# Product           object
# Product Line      object
# Product Type      object
# State             object
# Type              object
# Budget COGS        int64
# Budget Margin      int64
# Budget Profit      int64
# Budget Sales       int64
# COGS               int64
# Inventory          int64
# Margin             int64
# Marketing          int64
# Profit             int64
# Sales              int64
# Total Expenses     int64
# dtype: object

# %%
coffee.isnull().sum()
# Out:
# Area Code         0
# Market            0
# Market Size       0
# Product           0
# Product Line      0
# Product Type      0
# State             0
# Type              0
# Budget COGS       0
# Budget Margin     0
# Budget Profit     0
# Budget Sales      0
# COGS              0
# Inventory         0
# Margin            0
# Marketing         0
# Profit            0
# Sales             0
# Total Expenses    0
# dtype: int64

# %% [markdown]
# 1) Read the dataset
# 2) Remove/handle the null values
# 3) Depict different Market types and their count on a bar chart

# %%
# 3
coffee['Market'].value_counts()
# Out:
# Market
# Central    1344
# West       1344
# East        888
# South       672
# Name: count, dtype: int64

# %%
plt.bar(coffee['Market'].unique(),coffee['Market'].value_counts()) #here problem is market order and their value count will not be
# in the same order as value_counts always give results in desc order 
plt.show()

# %%
market_counts = coffee['Market'].value_counts()

# %%
# ANSWER 3

for i in range(len(market_counts)):
    plt.annotate(xy=[xval[i]-0.2,yval[i]+10],text=yval[i])
    
market_counts = coffee['Market'].value_counts()
xval1 = market_counts.index
yval = market_counts.values
plt.bar(xval1,yval,label='Market')
plt.title('Count of Markets')
plt.xlabel('Markets')
plt.ylabel('Count')
plt.legend()
plt.xticks(rotation=45)  # Control the angle of x-axis labels
plt.yticks(list(range(0,1600,400)))  # Control which values show on y-axis # 400 is the gap you want
plt.show()
plt.show()
# we are looking for x coordinates in plt.annotate then we are using list and range up till leng of coffe, how come it is giving central, west and so on

# %% [markdown]
# Depict different Product types and their count on a line chart

# %%
Product_counts = coffee['Product Type'].value_counts()
xval1 = Product_counts.index
yval = Product_counts.values
Product_counts
# Out:
# Product Type
# Espresso      1176
# Coffee        1056
# Herbal Tea    1056
# Tea            960
# Name: count, dtype: int64

# %%
plt.plot(xval1,yval,color = 'yellow')
for i in range(len(Product_counts)):
    plt.annotate(xy = [xval[i]-0.1,yval[i]], text = yval[i])
plt.title('Product_Counts')
plt.xlabel('Product_Type')
plt.ylabel('Count')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Depict different State and its count(as percentage of total) on a pie chart

# %%
plt.pie(x=val,labels = lab, autopct='%.2f%%')
plt.show()
# how to fit lable and percentage

# %% [markdown]
#  Depict Market wise sum of Profit and depict the result on bar chart.

# %%
# 6
ps = coffee.groupby(['Market'])['Profit'].sum()
xv = ps.index
yv = ps.values
plt.bar(xv,yv)
plt.show()

# %% [markdown]
# 7) Depict Product wise mean of Sales and depict the result on bar chart and line chart superimposed

# %%
plt.figure(figsize=(12,5))
pm = coffee.groupby(['Product'])['Sales'].mean()
xv = pm.index
yv = pm.values
plt.bar(xv,yv)
plt.xticks(rotation = 60)
sv1 = list(range(0,len(coffee)))
for i in range(len(pm)):
    plt.annotate(xy=[sv1[i]-0.4,yv[i]+10],text=round(yv[i],2))

plt.plot(xv,yv)
plt.show()

# %% [markdown]
# Depict Profit vs Sales on a Scatter Chart where Product is 'Regular Espresso'

# %%
# plt.scatter(x, y, label=None, color=None, marker='o', s=None, alpha=None)
rs = coffee[coffee['Product']=='Regular Espresso']
plt.scatter(rs['Sales'],rs['Profit'])
plt.show()

# %%
# 9 Depict Budget Profit vs Budget Sales on a Scatter Chart where State is California and Product is 'Earl Grey'

# %%
sp = coffee[(coffee['State']=='California') & (coffee['Product']=='Earl Grey')]
plt.scatter(sp['Budget Sales'],sp['Budget Profit'])
plt.show()

# %% [markdown]
#  Depict Market wise mean of Budget Sales and mean of Sales in a stacked bar chart

# %%
n1 = coffee.groupby(['Market'])[['Budget Sales','Sales']].mean()
n1
# Out:
#          Budget Sales       Sales
# Market
# Central    186.279762  197.206101
# East       177.815315  201.099099
# South      146.130952  154.651786
# West       178.348214  202.577381

# %%
n1.plot(kind='bar')
plt.show()

# %% [markdown]
# Plot the Frequency distribution of Total Expenses

# %%
# plt.hist(data, bins=None, color=None, edgecolor=None, alpha=None, label=None)
# data = Array or list of values (e.g., a numerical column from a DataFrame)

# %%
coffee['Total Expenses']
# Out:
# 0        36
# 1        39
# 2        38
# 3        26
# 4        26
#        ...
# 4243     19
# 4244     57
# 4245     45
# 4246     46
# 4247    125
# Name: Total Expenses, Length: 4248, dtype: int64

# %%
plt.hist(coffee['Total Expenses'])
# min expense is 10 and max is 190 so all the possible bins have been made between 10 and 190, now these are present on x-axis
# the frequency for each bin is depicted on y - axis
plt.show()

# %%
# Axis	       What it shows 	                              Example
# X-axis	 Value ranges (called bins)	                    e.g., salary ranges: 0–10k, 10–20k
# Y-axis	 Frequency (how many values fall in each bin)	e.g., number of people in each salary range

# %%
coffee['Total Expenses'].min()
# Out:
# 10
